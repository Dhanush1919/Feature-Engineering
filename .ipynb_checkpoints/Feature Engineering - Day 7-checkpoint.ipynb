# %% [markdown]
# ### Feature selection techniques

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df =pd.read_csv('mobile_dataset.csv')

# %%
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
df.isnull().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %% [markdown]
# #### Univariate selection:

# %%
X = df.iloc[:,:-1] #Not considering the last column alone
Y = df['price_range']

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
ordered_rank_features = SelectKBest(score_func=chi2,k=20)
ordered_features = ordered_rank_features.fit(X,Y)

# %%
ordered_features
# Out:
# SelectKBest(k=20, score_func=<function chi2 at 0x000001523EF95940>)

# %%
ordered_features.scores_
# Out:
# array([1.41298666e+04, 7.23232323e-01, 6.48365906e-01, 6.31010795e-01,
#        1.01351665e+01, 1.52157239e+00, 8.98391244e+01, 7.45819631e-01,
#        9.59728626e+01, 9.09755558e+00, 9.18605355e+00, 1.73635695e+04,
#        9.81058675e+03, 9.31267519e+05, 9.61487832e+00, 1.64803191e+01,
#        1.32364000e+01, 3.27642810e-01, 1.92842942e+00, 4.22090730e-01])

# %%
Scores = pd.DataFrame(ordered_features.scores_)
Feature = pd.DataFrame(X.columns)

# %%
Rank_values = pd.concat([Feature,Scores],axis=1)

# %%
Rank_values.columns = ['Feature_name','Score']

# %%
Rank_values
# Out:
#      Feature_name          Score
# 0   battery_power   14129.866576
# 1            blue       0.723232
# 2     clock_speed       0.648366
# 3        dual_sim       0.631011
# 4              fc      10.135166
# 5          four_g       1.521572
# 6      int_memory      89.839124
# 7           m_dep       0.745820
# 8       mobile_wt      95.972863
# 9         n_cores       9.097556
# 10             pc       9.186054
# 11      px_height   17363.569536
# 12       px_width    9810.586750
# 13            ram  931267.519053
# 14           sc_h       9.614878
# 15           sc_w      16.480319
# 16      talk_time      13.236400
# 17        three_g       0.327643
# 18   touch_screen       1.928429
# 19           wifi       0.422091

# %%
# Top 10 important features:
Rank_values.nlargest(10,'Score')
# Out:
#      Feature_name          Score
# 13            ram  931267.519053
# 11      px_height   17363.569536
# 0   battery_power   14129.866576
# 12       px_width    9810.586750
# 8       mobile_wt      95.972863
# 6      int_memory      89.839124
# 15           sc_w      16.480319
# 16      talk_time      13.236400
# 4              fc      10.135166
# 14           sc_h       9.614878

# %% [markdown]
# ### Feature Importance :
# This technique gives a score to each feature , higher the score , more relevant it is

# %%
from sklearn.ensemble import ExtraTreesClassifier

# %%
model = ExtraTreesClassifier()
model.fit(X,Y)
print(model.feature_importances_)
# Out:
# [0.06035814 0.02069464 0.03436888 0.02036619 0.0346754  0.01715745
#  0.03664102 0.03457552 0.03805676 0.03428274 0.03501755 0.04774045
#  0.04899081 0.37633518 0.03453216 0.03559911 0.03662347 0.01449469
#  0.01883351 0.02065632]

# %%
# Visualizing the series:
Feature_series = pd.Series(model.feature_importances_,X.columns)
Feature_series.nlargest(10).plot(kind='barh')
plt.show()

# %% [markdown]
# ### Correlation:

# %%
df.corr()
# Out:
#                battery_power      blue  clock_speed  dual_sim        fc  \
# battery_power       1.000000  0.011252     0.011482 -0.041847  0.033334
# blue                0.011252  1.000000     0.021419  0.035198  0.003593
# clock_speed         0.011482  0.021419     1.000000 -0.001315 -0.000434
# dual_sim           -0.041847  0.035198    -0.001315  1.000000 -0.029123
# fc                  0.033334  0.003593    -0.000434 -0.029123  1.000000
# four_g              0.015665  0.013443    -0.043073  0.003187 -0.016560
# int_memory         -0.004004  0.041177     0.006545 -0.015679 -0.029133
# m_dep               0.034085  0.004049    -0.014364 -0.022142 -0.001791
# mobile_wt           0.001844 -0.008605     0.012350 -0.008979  0.023618
# n_cores            -0.029727  0.036161    -0.005724 -0.024658 -0.013356
# pc                  0.031441 -0.009952    -0.005245 -0.017143  0.644595
# px_height           0.014901 -0.006872    -0.014523 -0.020875 -0.009990
# ...

# %%
import seaborn as sns
corr = df.corr()
top_features = corr.index

# %%
top_features
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
plt.figure(figsize=(20,20))
sns.heatmap(corr,cmap='BrBG',annot=True)
plt.show()

# %%
dataset = df.iloc[:,:-1].corr()
len(dataset.columns)
# Out:
# 20

# %%
# Getting the highly correlated columns: (checks lower triangular) 
def correlation(dataset,threshold):
    corr_matrix = dataset.corr()
    col_name = set()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i,j]) > threshold:
                cols = corr_matrix.columns[i]
                col_name.add(cols)
    return col_name

# %%
correlation(df.iloc[:,:-1],0.5)
# Out:
# {'pc', 'px_width', 'sc_w', 'three_g'}

# %% [markdown]
# ### Information gain:

# %%
from sklearn.feature_selection import mutual_info_classif

# %%
values = mutual_info_classif(X,Y)

# %%
top_features = pd.Series(values,index=X.columns)

# %%
# The Features with higher value is imp , while the feature with lower value or 0 can be ignored:
top_features.sort_values(ascending=False)
# Out:
# ram              0.846301
# three_g          0.031613
# px_height        0.029850
# px_width         0.027046
# mobile_wt        0.024363
# four_g           0.022820
# battery_power    0.022359
# wifi             0.019414
# sc_h             0.017398
# n_cores          0.013760
# m_dep            0.012976
# fc               0.012932
# pc               0.010932
# blue             0.005914
# touch_screen     0.005682
# sc_w             0.000000
# int_memory       0.000000
# talk_time        0.000000
# dual_sim         0.000000
# clock_speed      0.000000
# dtype: float64
